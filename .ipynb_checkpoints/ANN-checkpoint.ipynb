# %%
from keras.datasets import mnist # load mnist dataset
from keras.utils import to_categorical # converts labels to one-hot format
# EarlyStopping : If the validation loss does not improve, stop training early.
# ModelCheckpoint : saves the best model to disk
from keras.callbacks import EarlyStopping, ModelCheckpoint 
from keras.models import Sequential # simple model structure where you add layers one by one
from keras.layers import Dense # fully-connected layer
from keras.models import load_model
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
(X_train, y_train) , (X_test, y_test) = mnist.load_data()

# %%
plt.figure(figsize=(15,5))
for i in range(9):
    plt.subplot(3, 3 , i+1)
    plt.imshow(X_train[i], cmap="gray")
    plt.title(f"index: {i}, Label: {y_train[i]}")
    plt.axis("off")
plt.show()

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1]*X_train.shape[2])).astype("float32")/255
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1]*X_test.shape[2])).astype("float32")/255

# %%
X_train.shape # The dense (ANN) layer requires 2D data. This process is called flattening. It is not required in CNN.
# Out:
# (60000, 784)

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
model = Sequential()

# %%
model.add(Dense(512, activation= 'relu', input_shape = (28*28,)))
model.add(Dense(256, activation="tanh"))
model.add(Dense(10, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 535,818 (2.04 MB)
#  Trainable params: 535,818 (2.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %%
# define early_stopping
early_stopping = EarlyStopping(monitor = "val_loss", patience=5, restore_best_weights=True)

# %%
# define ModelCheckpoint
checkpoint = ModelCheckpoint("ann_best_model.keras", monitor = "val_loss", save_best_only=True)

# %%
# training the ann model
history = model.fit(X_train, y_train,
          epochs=10, 
          batch_size = 60,
          validation_split=0.2,
          callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8892 - loss: 0.3665 - val_accuracy: 0.9663 - val_loss: 0.1068
# Epoch 2/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9741 - loss: 0.0822 - val_accuracy: 0.9702 - val_loss: 0.0920
# Epoch 3/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9843 - loss: 0.0487 - val_accuracy: 0.9754 - val_loss: 0.0806
# Epoch 4/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9880 - loss: 0.0360 - val_accuracy: 0.9682 - val_loss: 0.1119
# Epoch 5/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9913 - loss: 0.0271 - val_accuracy: 0.9771 - val_loss: 0.0874
# Epoch 6/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9913 - loss: 0.0230 - val_accuracy: 0.9744 - val_loss: 0.0997
# Epoch 7/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0167 - val_accuracy: 0.9782 - val_loss: 0.0969
# Epoch 8/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9944 - loss: 0.0167 - val_accuracy: 0.9751 - val_loss: 0.0996

# %%
# model evaluation
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test acc: {test_acc}, test loss: {test_loss}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.9749 - loss: 0.0812
# Test acc: 0.9775999784469604, test loss: 0.06905055791139603

# %%
# training and validation accuracy visualization 
plt.figure()
plt.plot(history.history["accuracy"], marker = "o", label = "Training Accuracy")
plt.plot(history.history["val_accuracy"], marker = "o", label = "Validation Accuracy")
plt.title("ANN Accuracy on MNIST Data Set")
plt.xlabel("Epochs")
plt.ylabel("Acc")
plt.legend()
plt.grid(True)
plt.show()

# %%
# training and validation loss visualization
plt.figure()
plt.plot(history.history["loss"], marker = "o", label = "Training Loss")
plt.plot(history.history["val_loss"], marker = "o", label = "Validation Loss")
plt.title("ANN Loss on MNIST Data Set")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Save model
model.save("final_mnist_ann_model.keras")

# %%
loaded_model = load_model("final_mnist_ann_model.keras")

# %%
test_loss, test_acc = loaded_model.evaluate(X_test, y_test)
print(f"Loaded Model Result -> Test acc: {test_acc}, test loss: {test_loss}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - accuracy: 0.9749 - loss: 0.0812
# Loaded Model Result -> Test acc: 0.9775999784469604, test loss: 0.06905055791139603

# %%
# Predict model
import numpy as np
from PIL import Image, ImageOps

model = load_model("final_mnist_ann_model.keras")

def preprocess_paint_digit(
    image_path: str,
    target_size: int = 28,
    pad: int = 8,
    auto_invert: bool = True,
    crop_to_content: bool = True
) -> np.ndarray:
   
    img = Image.open(image_path).convert("L")

    if crop_to_content:
        arr = np.array(img)
        mask = arr > 20
        if mask.any():
            ys, xs = np.where(mask)
            x0, x1 = xs.min(), xs.max()
            y0, y1 = ys.min(), ys.max()
            img = img.crop((x0, y0, x1 + 1, y1 + 1))

    w, h = img.size
    side = max(w, h) + 2 * pad
    square = Image.new("L", (side, side), color=0)
    square.paste(img, ((side - w) // 2, (side - h) // 2))
    img = square

    if auto_invert:
        arr = np.array(img).astype(np.float32)
        if arr.mean() > 127:
            img = ImageOps.invert(img)

    img = img.resize((target_size, target_size), resample=Image.Resampling.BILINEAR)

    x = (np.array(img).astype("float32") / 255.0).reshape(1, target_size * target_size)
    return x

def predict_paint_digit(image_path: str, show: bool = True) -> int:
    x = preprocess_paint_digit(image_path)
    probs = model.predict(x, verbose=0)[0]
    pred = int(np.argmax(probs))

    if show:
        plt.imshow(x.reshape(28, 28), cmap="gray")
        plt.title(f"Tahmin: {pred} | Guven: {probs[pred]:.3f}")
        plt.axis("off")
        plt.show()

    return pred

pred = predict_paint_digit("digit.png", show=True)
print("predict number: ", pred)
# Out:
# predict number:  3
